# %%
import numpy as np 
import pandas as pd
import string
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
en_stopwords = stopwords.words('english')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/KHTN_DS/Course2/Test
# Out:
# /content/drive/.shortcut-targets-by-id/1wQRlFpi5Y9nti063o6-RSRGXOUHz9B4w/KHTN_DS/Course2/Test

# %%
book_df = pd.read_csv('prog_book.csv')
book_df
# Out:
#      Rating Reviews  ...                   Type       Price
# 0      4.17   3,829  ...              Hardcover    9.323529
# 1      4.01   1,406  ...              Hardcover   11.000000
# 2      3.33       0  ...         Kindle Edition   11.267647
# 3      3.97   1,658  ...              Hardcover   12.873529
# 4      4.06   1,325  ...         Kindle Edition   13.164706
# ..      ...     ...  ...                    ...         ...
# 266    3.76       0  ...              Hardcover  203.108823
# 267    3.94      22  ...              Paperback  212.097059
# 268    4.49      36  ...  Boxed Set - Hardcover  220.385294
# 269    4.77       4  ...              Hardcover  220.385294
# 270    3.84       5  ...              Hardcover  235.650000
#
# [271 rows x 7 columns]

# %%
titles = book_df['Book_title'].tolist()

# %%
filtered_tokens = []
for title in titles:
  tokens = word_tokenize(title)
  filtered_tokens.extend([token for token in tokens if (token.lower() not in en_stopwords) and (token.lower() not in string.punctuation)])

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(" ".join(filtered_tokens))
                 
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
leaf_mask = np.array(Image.open("lacay.png"))

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                mask=leaf_mask,
                min_font_size = 10).generate(" ".join(filtered_tokens))
                     
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
