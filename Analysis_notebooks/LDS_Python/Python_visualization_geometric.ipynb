# %% [markdown]
# ## Chapter 8 - Exercise 1: Geojson_hcmc

# %%
# !pip install geopandas

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
import fiona
fiona.supported_drivers
# Out:
# {'ARCGEN': 'r',
#  'CSV': 'raw',
#  'DGN': 'raw',
#  'DXF': 'rw',
#  'ESRI Shapefile': 'raw',
#  'ESRIJSON': 'r',
#  'FlatGeobuf': 'rw',
#  'GML': 'rw',
#  'GPKG': 'raw',
#  'GPSTrackMaker': 'rw',
#  'GPX': 'rw',
#  'GeoJSON': 'raw',
#  'GeoJSONSeq': 'rw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'OGR_GMT': 'rw',
#  'OGR_PDS': 'r',
#  'OpenFileGDB': 'r',
#  'S57': 'r',
#  'SQLite': 'raw',
#  'TopoJSON': 'r'}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/KHTN_DS/Course2/Chapter8
# Out:
# /content/drive/MyDrive/KHTN_DS/Course2/Chapter8

# %% [markdown]
# #### Thực hiện các yêu cầu sau, và đối chiếu với kết quả cho trước:

# %%
# Câu 1: Đọc file dữ liệu ranh giới các quận - khu vực của TP.HCM (district-boundary-hcm-city.geojson)
geo_df = gpd.read_file(r'district-boundary-hcm-city.geojson')
geo_df.head(5)
# Out:
#         id  ...                                           geometry
# 0  3850184  ...  MULTIPOLYGON (((106.69344 10.72213, 106.69475 ...
# 1  3797166  ...  MULTIPOLYGON (((106.68386 10.80711, 106.68388 ...
# 2  2587287  ...  MULTIPOLYGON (((106.68165 10.76543, 106.68187 ...
# 3  3819816  ...  MULTIPOLYGON (((106.66422 10.78714, 106.66457 ...
# 4  2778323  ...  MULTIPOLYGON (((106.68639 10.75184, 106.68641 ...
#
# [5 rows x 8 columns]

# %%
# Hiển thị 5 dòng đầu của dữ liệu

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_html rendered_html output_result"><div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>localname</th>
#       <th>timestamp</th>
#       <th>SRID</th>
#       <th>admin_level</th>
#       <th>tags</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3850184</td>
#       <td>Saigon South</td>
#       <td>Khu đô thị Nam Sài Gòn</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>5</td>
#       <td>{'name': 'Khu đô thị Nam Sài Gòn', 'name:en': ...</td>
#       <td>MULTIPOLYGON (((106.69344 10.72213, 106.69475 ...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3797166</td>
#       <td>Binh Thanh District</td>
#       <td>Quận Bình Thạnh</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>6</td>
#       <td>{'name': 'Quận Bình Thạnh', 'name:en': 'Binh T...</td>
#       <td>MULTIPOLYGON (((106.68386 10.80711, 106.68388 ...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2587287</td>
#       <td>District 1</td>
#       <td>Quận 1</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>6</td>
#       <td>{'name': 'Quận 1', 'name:en': 'District 1', 'n...</td>
#       <td>MULTIPOLYGON (((106.68165 10.76543, 106.68187 ...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3819816</td>
#       <td>District 3</td>
#       <td>Quận 3</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>6</td>
#       <td>{'name': 'Quận 3', 'name:en': 'District 3', 'n...</td>
#       <td>MULTIPOLYGON (((106.66422 10.78714, 106.66457 ...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2778323</td>
#       <td>District 4</td>
#       <td>Quận 4</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>6</td>
#       <td>{'name': 'Quận 4', 'name:en': 'District 4', 'b...</td>
#       <td>MULTIPOLYGON (((106.68639 10.75184, 106.68641 ...</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#
# </details>

# %%
# Hiển thị 5 dòng cuối của dữ liệu
geo_df.tail(5)
# Out:
#          id  ...                                           geometry
# 8   3799817  ...  MULTIPOLYGON (((106.70820 10.77141, 106.70822 ...
# 9   3851694  ...  MULTIPOLYGON (((106.66592 10.79081, 106.66602 ...
# 10  3853748  ...  MULTIPOLYGON (((106.67805 10.72485, 106.67923 ...
# 11  3854476  ...  MULTIPOLYGON (((106.67912 10.71991, 106.68094 ...
# 12  3854477  ...  MULTIPOLYGON (((106.68321 10.71349, 106.68369 ...
#
# [5 rows x 8 columns]

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_html rendered_html output_result"><div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>localname</th>
#       <th>timestamp</th>
#       <th>SRID</th>
#       <th>admin_level</th>
#       <th>tags</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>3799817</td>
#       <td>Quận 2</td>
#       <td>Quận 2</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>6</td>
#       <td>{'name': 'Quận 2', 'boundary': 'administrative...</td>
#       <td>MULTIPOLYGON (((106.70820 10.77141, 106.70822 ...</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>3851694</td>
#       <td>Quận Phú Nhuận</td>
#       <td>Quận Phú Nhuận</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>6</td>
#       <td>{'name': 'Quận Phú Nhuận', 'boundary': 'admini...</td>
#       <td>MULTIPOLYGON (((106.66592 10.79081, 106.66602 ...</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>3853748</td>
#       <td>Khu 6</td>
#       <td>Khu 6</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>9</td>
#       <td>{'name': 'Khu 6', 'boundary': 'administrative'...</td>
#       <td>MULTIPOLYGON (((106.67805 10.72485, 106.67923 ...</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>3854476</td>
#       <td>Dai Phuc Residences</td>
#       <td>Khu Nhà ở Rạch Bà Tánh</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>10</td>
#       <td>{'name': 'Khu Nhà ở Rạch Bà Tánh', 'name:en': ...</td>
#       <td>MULTIPOLYGON (((106.67912 10.71991, 106.68094 ...</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>3854477</td>
#       <td>T30 Residential Area</td>
#       <td>Khu Dân cư T30</td>
#       <td>2016-03-18T23:05:02</td>
#       <td>4326</td>
#       <td>10</td>
#       <td>{'name': 'Khu Dân cư T30', 'name:en': 'T30 Res...</td>
#       <td>MULTIPOLYGON (((106.68321 10.71349, 106.68369 ...</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#
# </details>

# %%
# Hiển thị bản đồ ranh giới từ dữ liệu district, cmap = 'Set2' 
geo_df.plot(column='name',cmap='Set2',figsize=(8,6))
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 2: Đọc dữ liệu trong sheet 'location' của file HCMC_location.xlsx
xlsx = pd.ExcelFile('HCMC_location.xlsx')
gdf_loca = pd.read_excel('HCMC_location.xlsx',sheet_name='Location')
# Hiển thị 5 dòng đầu của dữ liệu
gdf_loca.head(5)
# Out:
#    STT   ID          Name  ... Population  Population_all  Avg_land_price
# 0    1  760        Quận 1  ...    193.632          193632        59852096
# 1    2  761       Quận 12  ...    510.326          510326         3505942
# 2    3  762  Quận Thủ Đức  ...    528.413          528413         5249286
# 3    4  763        Quận 9  ...    290.620          290620         3337584
# 4    5  764   Quận Gò Vấp  ...    634.146          634146         9873267
#
# [5 rows x 10 columns]

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_html rendered_html output_result"><div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>STT</th>
#       <th>ID</th>
#       <th>Name</th>
#       <th>Bourough</th>
#       <th>Postal cost</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Population</th>
#       <th>Population_all</th>
#       <th>Avg_land_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>760</td>
#       <td>Quận 1</td>
#       <td>Vietnam, Quan 1</td>
#       <td>NaN</td>
#       <td>10.775659</td>
#       <td>106.700424</td>
#       <td>193.632</td>
#       <td>193632</td>
#       <td>59852096</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>761</td>
#       <td>Quận 12</td>
#       <td>Vietnam, Quan 12</td>
#       <td>NaN</td>
#       <td>10.867153</td>
#       <td>106.641332</td>
#       <td>510.326</td>
#       <td>510326</td>
#       <td>3505942</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>762</td>
#       <td>Quận Thủ Đức</td>
#       <td>Vietnam, Thu Duc</td>
#       <td>NaN</td>
#       <td>10.849409</td>
#       <td>106.753705</td>
#       <td>528.413</td>
#       <td>528413</td>
#       <td>5249286</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>763</td>
#       <td>Quận 9</td>
#       <td>Vietnam, Quan 9</td>
#       <td>NaN</td>
#       <td>10.842840</td>
#       <td>106.828685</td>
#       <td>290.620</td>
#       <td>290620</td>
#       <td>3337584</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>764</td>
#       <td>Quận Gò Vấp</td>
#       <td>Vietnam, Go Vap</td>
#       <td>NaN</td>
#       <td>10.838678</td>
#       <td>106.665290</td>
#       <td>634.146</td>
#       <td>634146</td>
#       <td>9873267</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#
# </details>

# %%
# Câu 3: Vẽ scatterplot với dữ liệu Longitude, Latitude của dữ liệu của câu 2
plt.figure(figsize=(10,8))
plt.scatter(gdf_loca.Longitude,gdf_loca.Latitude)
plt.title('HCMC districts Longtitude and Latitude')
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 4: Vẽ bản đồ thể hiện vị trí các quận-khu vực tại TP.HCM
geo_df.plot(column='name',
            cmap='Set2',
            figsize=(20,18),
            legend=True,
)
plt.scatter(gdf_loca.Longitude,gdf_loca.Latitude)
plt.title('HCMC districts Longtitude and Latitude')
plt.grid()
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>
